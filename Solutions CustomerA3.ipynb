# %%
#Show DataFrame info.

# %%
import pandas as pd
import numpy as np 
import datetime
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
df = pd.read_csv("/Users/aloaskari/Desktop/Ironhack/Bootcamp/Week_1/Day_3/Morning/Lab_3/clone/lab-customer-analysis-round-3/files_for_lab/csv_files/marketing_customer_analysis.csv")

df = (df.reset_index(drop = True))

df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
#Describe DataFrame.

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
#Show a plot of the total number of responses.

# %%
df['Response'].value_counts().plot(kind='bar')
plt.title("Total Number of Responses")
plt.xlabel("Responses")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
#responses = df['Response']

# %%
#responses.head()

# %%
#def clean(x): 
    #if x in ["Yes"]:
        #return "1"
    #elif x in ["No"]:
        #return "0"
    #else: 
        #return x

# %%
#responses = responses.apply(clean)

# %%
#Show a plot of the response rate by the sales channel.

# %%
df3 = df[['Response', 'Sales Channel']]

# %%
df3.head()
# Out:
#   Response Sales Channel
# 0       No         Agent
# 1       No         Agent
# 2       No         Agent
# 3       No   Call Center
# 4       No         Agent

# %%
df3.value_counts()
# Out:
# Response  Sales Channel
# No        Agent            2811
#           Branch           2273
#           Call Center      1573
#           Web              1169
# Yes       Agent             666
#           Branch            294
#           Call Center       192
#           Web               156
# dtype: int64

# %%
df3.value_counts().plot(kind='bar')
plt.title("Responses by Channel")
plt.xlabel("Channel")
plt.ylabel("Responses")
# Out:
# Text(0, 0.5, 'Responses')

# %%
#Show a plot of the response rate by the total claim amount

# %%
df["Total Claim Amount"] = round(df["Total Claim Amount"], 2)

# %%
q1_tca = np.quantile(df["Total Claim Amount"], q=0.25)

# %%
q2_tca = np.quantile(df["Total Claim Amount"], q=0.5)

# %%
q3_tca = np.quantile(df["Total Claim Amount"], q=0.75)

# %%
df4 = pd.DataFrame(df[['Response', 'Total Claim Amount']])

# %%
Total_Claim_Amount = df4["Total Claim Amount"]

# %%
Responses = df4["Response"]

# %%
df4.head()
# Out:
#   Response  Total Claim Amount
# 0       No              384.81
# 1       No             1131.46
# 2       No              566.47
# 3       No              529.88
# 4       No              138.13

# %%
df4.dtypes
# Out:
# Response               object
# Total Claim Amount    float64
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(y=Responses, x=Total_Claim_Amount, s=[50])
ax.set_xlabel("Total Claim Amount")
ax.set_ylabel("Responses")
ax.set_title("Response Rate by Total Claim Amount")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data = df, y=df['Response'], x=df['Total Claim Amount'], ax = ax)
ax.set_xlabel("Total Claim Amount")
ax.set_ylabel("Responses")
ax.set_title("Response Rate by Total Claim Amount")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, y=df['Total Claim Amount'], x=df['Response'])
ax.set_xlabel("Total Claim Amount")
ax.set_ylabel("Responses")
ax.set_title("Response Rate by Total Claim Amount")
plt.show()

# %%
#Show a plot of the response rate by income.

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data = df, y=df['Total Claim Amount'], x=df['Response'], ax = ax)
ax.set_xlabel("Response")
ax.set_ylabel("Total Claim Amount")
ax.set_title("Response Rate by Total Claim Amount")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data = df, y=df['Response'], x=df['Total Claim Amount'], ax = ax)
ax.set_xlabel("Total Claim Amount")
ax.set_ylabel("Response")
ax.set_title("Response Rate by Total Claim Amount")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df['Total Claim Amount'], x=df['Response'])
ax.set_xlabel("Total Claim Amount")
ax.set_ylabel("Responses")
ax.set_title("Response Rate by Total Claim Amount")
plt.show()

# %%
#Show a plot of the response rate by income.

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data = df, y=df['Response'], x=df['Income'], ax = ax)
ax.set_xlabel("Income")
ax.set_ylabel("Response")
ax.set_title("Response Rate by Income")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, y=df['Income'], x=df['Response'])
ax.set_xlabel("Income")
ax.set_ylabel("Responses")
ax.set_title("Response Rate by Income")
plt.show()
